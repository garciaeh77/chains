# %%
import sys, os
sys.path.insert(0,os.path.realpath(os.path.join(os.getcwd(),'..')))
from getdist import plots, MCSamples
import getdist
import matplotlib.pyplot as plt
import IPython
print('GetDist Version: %s, Matplotlib version: %s'%(getdist.__version__, plt.matplotlib.__version__))
# matplotlib 2 may not work very well without usetex on, can uncomment
# plt.rcParams['text.usetex']=True
import getdist.plots as gdplt
from getdist import plots
# Out:
# GetDist Version: 1.3.2, Matplotlib version: 3.4.2

# %%
# Triangle plot
g0 = plots.get_subplot_plotter(chain_dir='/home/usuario/Helena/Kevork/Cobaya/chain_analysis/1_Planck2018_LCDM_w_mnu_mcmc_2ndtr')
g0.triangle_plot(['1_Planck2018_LCDM_w_mnu_mcmc_2ndtr','1_Planck2018_LCDM_w_mnu_mcmc_2ndtr.post.canac_h0ries2020','1_Planck2018_LCDM_w_mnu_mcmc_2ndtr.post._h0ries2020','1_Planck2018_LCDM_w_mnu_mcmc_2ndtr.post.canac'], ["w","mnu"], filled=True)
g0.export('Planck2018_LCDM_w_mnu_4models.pdf')

# %%
# Triangle plot
g1 = plots.get_subplot_plotter(chain_dir='/home/usuario/Helena/Kevork/Cobaya/chain_analysis/1_Planck2018_LCDM_w_mnu_mcmc_2ndtr')
g1.triangle_plot(['1_Planck2018_LCDM_w_mnu_mcmc_2ndtr','1_Planck2018_LCDM_w_mnu_mcmc_2ndtr.post.canac_h0ries2020','1_Planck2018_LCDM_w_mnu_mcmc_2ndtr.post._h0ries2020'], ["w","mnu"], filled=True)

# %%
# Triangle plot
g2 = plots.get_subplot_plotter(chain_dir='/home/usuario/Helena/Kevork/Cobaya/chain_analysis/1_Planck2018_LCDM_w_mnu_mcmc_2ndtr')
g2.triangle_plot(['1_Planck2018_LCDM_w_mnu_mcmc_2ndtr','1_Planck2018_LCDM_w_mnu_mcmc_2ndtr.post.canac_h0ries2020'], ["w","mnu"], filled=True)

# %%
# Triangle plot
g3 = plots.get_subplot_plotter(chain_dir='/home/usuario/Helena/Kevork/Cobaya/chain_analysis/1_Planck2018_LCDM_w_mnu_mcmc_2ndtr')
g3.triangle_plot(['1_Planck2018_LCDM_w_mnu_mcmc_2ndtr','1_Planck2018_LCDM_w_mnu_mcmc_2ndtr.post._h0ries2020'], ["w","mnu"], filled=True)

# %%
# Triangle plot
g4 = plots.get_subplot_plotter(chain_dir='/home/usuario/Helena/Kevork/Cobaya/chain_analysis/1_Planck2018_LCDM_w_mnu_mcmc_2ndtr')
g4.triangle_plot(['1_Planck2018_LCDM_w_mnu_mcmc_2ndtr.post.canac_h0ries2020','1_Planck2018_LCDM_w_mnu_mcmc_2ndtr.post._h0ries2020'], ["w","mnu"], filled=True)

# %%
# Triangle plot
g5 = plots.get_subplot_plotter(chain_dir='/home/usuario/Helena/Kevork/Cobaya/chain_analysis/1_Planck2018_LCDM_w_mnu_mcmc_2ndtr')
g5.triangle_plot(['1_Planck2018_LCDM_w_mnu_mcmc_2ndtr.post.canac_h0ries2020'], ["w"], filled=True)

# %%
# Triangle plot
#g1 = plots.get_subplot_plotter(chain_dir='/home/usuario/Helena/Kevork/Cobaya/chain_analysis/1_P_2018_LCDM_6p_and_w_chains1')
#g1.triangle_plot(['1_Planck2018_LCDM_mnu_mcmc'], ["mnu"], filled=True)

# %%
p = 1_Planck2018_LCDM_w_mnu_mcmc_2ndtr.post.canac_h0ries2020.getParams()
# Out:
#   File "<ipython-input-9-230e7ad18b24>", line 1
#     p = 1_Planck2018_LCDM_w_mnu_mcmc_2ndtr.post.canac_h0ries2020.getParams()
#          ^
# SyntaxError: invalid token

# %%
## g.export('output_file.pdf')
